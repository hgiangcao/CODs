# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
from spartan_dataset_masked import SpartanDataset
import dense_correspondence_manipulation.utils.utils as utils

utils.add_dense_correspondence_to_python_path()
import dense_correspondence.correspondence_tools.correspondence_finder as correspondence_finder
import dense_correspondence.correspondence_tools.correspondence_plotter as correspondence_plotter
from dense_correspondence.dataset.dense_correspondence_dataset_masked import ImageType

import os
import torch
import numpy as np
# %matplotlib inline

dataset_config_filename = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence',
                                       'dataset', 'composite',
                                       'Donkey.yaml')

dataset_config = utils.getDictFromYamlFilename(dataset_config_filename)

dataset = SpartanDataset(debug=True, config=dataset_config)
# Out:
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     34

# %%
error = True
tryTime = 0
while (error):
    try:

        match_type, image_a_rgb, image_b_rgb, \
        matches_a, matches_b, masked_non_matches_a, \
        masked_non_matches_a, non_masked_non_matches_a, \
        non_masked_non_matches_b, blind_non_matches_a, \
        blind_non_matches_b, metadata = dataset.get_single_object_within_scene_data()
        error = False
    except:
        tryTime +=1
print ((str)(tryTime) +" tries")
# Out:
# BUG HERE
# {'object_id_int': 0, 'scene_name': '000', 'type': 0, 'object_id': 'Donkey00'}
# (480, 640)
# (480, 640)
# {'image_a_idx': 2, 'object_id': 'Donkey00', 'scene_name': '000', 'object_id_int': 0, 'type': 0, 'image_b_idx': 13}
# (2, 13)
# (480, 640)
# (480, 640)
# HERE
# BUG HERE
# {'object_id_int': 0, 'scene_name': '000', 'type': 0, 'object_id': 'Donkey00'}
# (480, 640)
# (480, 640)
# {'image_a_idx': 19, 'object_id': 'Donkey00', 'scene_name': '000', 'object_id_int': 0, 'type': 0, 'image_b_idx': 1}
# (19, 1)
# (480, 640)
# (480, 640)
# HERE
# ((tensor([432, 387, 276, 266, 353]), tensor([297, 288, 226, 182, 386])), (tensor([258.3752, 258.7430, 259.6413, 259.7137, 259.0444]), tensor([442.6176, 442.6860, 443.2023, 443.5844, 441.8230])))
# Print from debuging
# 1 tries
